# %% [markdown]
# # Final Project
#
# Please fill out:
# * Student name: Seyma Tas
# * Student pace: full time
# * Scheduled project review date/time:
# * Instructor name: Amber Yandow
# * Blog post URL:

# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
sns.set(color_codes=True)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Set options

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Read datasets

# %%
movie_gross_df = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
imdb_name_basics_df = pd.read_csv ('zippedData/imdb.name.basics.csv.gz')
imdb_title_akas_df = pd.read_csv('zippedData/imdb.title.akas.csv.gz')
imdb_title_basics_df = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
imdb_title_crew_df = pd.read_csv('zippedData/imdb.title.crew.csv.gz')
imdb_title_principals_df = pd.read_csv('zippedData/imdb.title.principals.csv.gz')
imdb_title_ratings_df = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
## I am not loading movie_info_df because I decided to not use the unique info (synopsis) from this table in my project
# movie_info_df = pd.read_csv('zippedData/rt.movie_info.tsv.gz', delimiter='\t') 
## I am not loading reviews_df because I decided to not use the unique info (review) from this table in my project
# reviews_df = pd.read_csv('zippedData/rt.reviews.tsv.gz', encoding= 'unicode_escape', delimiter = '\t')
tmdb_movies_df = pd.read_csv('zippedData/tmdb.movies.csv')
movie_budgets_df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
money_df = pd.read_csv('zippedData/money.csv')

# %%
url = 'https://raw.githubusercontent.com/Jesse989/movie-analysis/master/data/interim/money.csv'
main_df = pd.read_csv(url, error_bad_lines=False)

# %%
money_df.head(500)
money_df.tail()
money_df.shape
money_df.info()
money_df['production_co'].nunique()
money_df['director'].nunique()
# Out:
#        imdb_id  \
# 0    tt2488496
# 1    tt4154796
# 2    tt0499549
# 3    tt1825683
# 4    tt4154756
# 5    tt0120338
# 6    tt0369610
# 7    tt0848228
# 8    tt2527336
# 9    tt3606756
# 10   tt6105098
# 11   tt0468569
# 12   tt3748528
# 13   tt2527338
# 14   tt2771200
# 15   tt2277860
# 16   tt4520988
# 17   tt0120915
# 18   tt0076759
# 19   tt2395427
# 20   tt1345836
# 21   tt0298148
# 22   tt0083866
# 23   tt1979376
# 24   tt4154664
# 25   tt1951264
# 26   tt0383574
# 27   tt0110357
# 28   tt4881806
# 29   tt0435761
# 30   tt0451279
# 31   tt1300854
# 32   tt3498820
# 33   tt1392170
# 34   tt0145487
# 35   tt2283362
# 36   tt0107290
# 37   tt1055369
# 38   tt2294629
# 39   tt6320628
# 40   tt3896198
# 41   tt1201607
# 42   tt0266543
# 43   tt0121766
# 44   tt0167260
# 45   tt0316654
# 46   tt0335345
# 483  Lorimar Film Entertainment                       [US]        3,527
# 484  DreamWorks                                       [US]        1,665
# 485  Imagine Entertainment                            [US]        4,756
# 486  Everyman Pictures                                [US]        3,893
# 487  Columbia Pictures                                [US]        1,352
# 488  Twentieth Century Fox                            [US]        426
# 489  Twentieth Century Fox Animation                  [US]        3,723
# 490  Paramount Pictures                               [US]        1,560
# 491  Asia Union Film & Entertainment Ltd.             NaN         3,039
# 492  Paramount Pictures                               [US]        273
# 493  Lucamar Productions                              [US]        2,335
# 494  United Artists                                   [US]        4,341
# 495  Walt Disney Pictures                             [US]        1,896
# 496  Warner Bros.                                     [US]        1,372
# 497  New Line Cinema                                  [US]        2,459
# 498  Paramount Pictures                               [US]        5,035
# 499  Touchstone Pictures                              [US]        3,133
#
#     budget_usd us_gross
# 0    $245MM     $937MM
# 1    $356MM     $858MM
# 2    $237MM     $761MM
# 3    $200MM     $700MM
# 4    $321MM     $679MM
# 5    $200MM     $659MM
# 6    $150MM     $652MM
# 7    $220MM     $623MM
# 8    $317MM     $620MM
# 9    $200MM     $609MM
# 10   $260MM     $544MM
# 11   $185MM     $535MM
# 12   $200MM     $532MM
# 13   $200MM     $515MM
# 14   $160MM     $504MM
# 15   $200MM     $486MM
# 16   $150MM     $477MM
# 17   $115MM     $475MM
# 18   $11MM      $461MM
# 19   $250MM     $459MM
# 20   $250MM     $448MM
# 21   $150MM     $441MM
# 22   $10MM      $435MM
# 23   $200MM     $434MM
# 24   $175MM     $427MM
# 25   $130MM     $425MM
# 26   $225MM     $423MM
# 27   $45MM      $423MM
# 28   $170MM     $418MM
# 29   $200MM     $415MM
# 30   $149MM     $413MM
# 31   $200MM     $409MM
# 32   $250MM     $408MM
# 33   $78MM      $408MM
# 34   $139MM     $407MM
# 35   $90MM      $405MM
# 36   $63MM      $403MM
# 37   $200MM     $402MM
# 38   $150MM     $401MM
# 39   $160MM     $391MM
# 40   $200MM     $390MM
# 41   $125MM     $381MM
# 42   $94MM      $381MM
# 43   $113MM     $380MM
# 44   $94MM      $378MM
# 45   $200MM     $374MM
# 46   $30MM      $371MM
# 47   $75MM      $368MM
# 48   $76MM      $368MM
# 49   $175MM     $364MM
# 50   $58MM      $363MM
# 51   $175MM     $356MM
# 52   $183MM     $356MM
# 53   $190MM     $353MM
# 54   $195MM     $352MM
# 55   $59MM      $350MM
# 56   $94MM      $343MM
# 57   $150MM     $341MM
# 58   $125MM     $337MM
# 59   $258MM     $337MM
# 60   $74MM      $336MM
# 61   $55MM      $335MM
# 62   $160MM     $335MM
# 63   $175MM     $334MM
# 64   $200MM     $334MM
# 65   $170MM     $333MM
# 66   $55MM      $330MM
# 67   $250MM     $330MM
# 68   $35MM      $329MM
# 69   $175MM     $325MM
# 70   $110MM     $325MM
# 71   $160MM     $323MM
# 72   $150MM     $319MM
# 73   $140MM     $319MM
# 74   $125MM     $318MM
# 75   $185MM     $317MM
# 76   $125MM     $317MM
# 77   $93MM      $316MM
# 78   $180MM     $315MM
# 79   $200MM     $312MM
# 80   $115MM     $311MM
# 81   $300MM     $309MM
# 82   $32MM      $309MM
# 83   $75MM      $306MM
# 84   $140MM     $305MM
# 85   $200MM     $304MM
# 86   $180MM     $303MM
# 87   $250MM     $302MM
# 88   $68MM      $301MM
# 89   $50MM      $298MM
# 90   £150MM     $296MM
# 91   $40MM      $294MM
# 92   $175MM     $293MM
# 93   $160MM     $293MM
# 94   $150MM     $292MM
# 95   $120MM     $292MM
# 96   $180MM     $292MM
# 97   $225MM     $291MM
# 98   $150MM     $290MM
# 99   $18MM      $290MM
# 100  $115MM     $290MM
# 101  $18MM      $286MM
# 102  $160MM     $282MM
# 103  $150MM     $282MM
# 104  $110MM     $281MM
# 105  $80MM      $279MM
# 106  $35MM      $277MM
# 107  $100MM     $274MM
# 108  $75MM      $271MM
# 109  $75MM      $270MM
# 110  $200MM     $268MM
# 111  $60MM      $268MM
# 112  $80MM      $265MM
# 113  $100MM     $262MM
# 114  $230MM     $262MM
# 115  $92MM      $261MM
# 116  $123MM     $260MM
# 117  $7MM       $260MM
# 118  $170MM     $260MM
# 119  $225MM     $258MM
# 120  $60MM      $258MM
# 121  $150MM     $258MM
# 122  $150MM     $256MM
# 123  $29MM      $256MM
# 124  $250MM     $255MM
# 125  $80MM      $254MM
# 126  $69MM      $252MM
# 127  $35MM      $251MM
# 128  $110MM     $251MM
# 129  $90MM      $251MM
# 130  $130MM     $250MM
# 131  $150MM     $249MM
# 132  $18MM      $248MM
# 133  $90MM      $246MM
# 134  $210MM     $245MM
# 135  $120MM     $244MM
# 136  $81MM      $243MM
# 137  $30MM      $243MM
# 138  $92MM      $242MM
# 139  $5MM       $241MM
# 140  $180MM     $241MM
# 141  $250MM     $241MM
# 142  $165MM     $239MM
# 143  $160MM     $239MM
# 144  $185MM     $237MM
# 145  $215MM     $235MM
# 146  $14MM      $235MM
# 147  $210MM     $234MM
# 148  $132MM     $234MM
# 149  $180MM     $234MM
# 150  $200MM     $234MM
# 151  $90MM      $234MM
# 152  $11MM      $233MM
# 153  $165MM     $233MM
# 154  $73MM      $229MM
# 155  $300MM     $229MM
# 156  $190MM     $229MM
# 157  $108MM     $228MM
# 158  $72MM      $228MM
# 159  $150MM     $228MM
# 160  $110MM     $227MM
# 161  $97MM      $226MM
# 162  $90MM      $226MM
# 163  $250MM     $226MM
# 164  $180MM     $224MM
# 165  $165MM     $223MM
# 166  $30MM      $222MM
# 167  $178MM     $220MM
# 168  $130MM     $220MM
# 169  $75MM      $220MM
# 170  $25MM      $219MM
# 171  $25MM      $219MM
# 172  $50MM      $219MM
# 173  $207MM     $218MM
# 174  $22MM      $218MM
# 175  $165MM     $218MM
# 176  $125MM     $218MM
# 177  $28MM      $217MM
# 178  $60MM      $217MM
# 179  $70MM      $217MM
# 180  $162MM     $217MM
# 181  $52MM      $216MM
# 182  $145MM     $216MM
# 183  $130MM     $215MM
# 184  $125MM     $215MM
# 185  $36MM      $215MM
# 186  $110MM     $215MM
# 187  $70MM      $214MM
# 188  $275MM     $214MM
# 189  $100MM     $214MM
# 190  $63MM      $213MM
# 191  $79MM      $212MM
# 192  $19MM      $211MM
# 193  $65MM      $211MM
# 194  $125MM     $210MM
# 195  $175MM     $210MM
# 196  $145MM     $209MM
# 197  $40MM      $209MM
# 198  $90MM      $209MM
# 199  $170MM     $209MM
# 200  $150MM     $207MM
# 201  $150MM     $206MM
# 202  $150MM     $206MM
# 203  $170MM     $206MM
# 204  $33MM      $206MM
# 205  $102MM     $206MM
# 206  $200MM     $203MM
# 207  $190MM     $202MM
# 208  $98MM      $202MM
# 209  $140MM     $202MM
# 210  $95MM      $201MM
# 211  $175MM     $201MM
# 212  $4MM       $201MM
# 213  $260MM     $201MM
# 214  $160MM     $201MM
# 215  $270MM     $200MM
# 216  $245MM     $200MM
# 217  $140MM     $199MM
# 218  $175MM     $198MM
# 219  $100MM     $198MM
# 220  $48MM      $197MM
# 221  $90MM      $197MM
# 222  $80MM      $195MM
# 223  $150MM     $195MM
# 224  $37MM      $194MM
# 225  $140MM     $194MM
# 226  $75MM      $194MM
# 227  $50MM      $192MM
# 228  $200MM     $191MM
# 229  $125MM     $191MM
# 230  $90MM      $190MM
# 231  $6MM       $190MM
# 232  $100MM     $190MM
# 233  $165MM     $189MM
# 234  $17MM      $188MM
# 235  $165MM     $188MM
# 236  $103MM     $188MM
# 237  $165MM     $187MM
# 238  $135MM     $187MM
# 239  $125MM     $187MM
# 240  $125MM     $187MM
# 241  $110MM     $186MM
# 242  $1.5MM     $185MM
# 243  $29MM      $184MM
# 244  $22MM      $184MM
# 245  $100MM     $184MM
# 246  $44MM      $184MM
# 247  $135MM     $184MM
# 248  $85MM      $183MM
# 249  $75MM      $183MM
# 250  $70MM      $183MM
# 251  $140MM     $183MM
# 252  $65MM      $182MM
# 253  $45MM      $181MM
# 254  $93MM      $181MM
# 255  $150MM     $181MM
# 256  $80MM      $181MM
# 257  $130MM     $180MM
# 258  $100MM     $180MM
# 259  $150MM     $180MM
# 260  $150MM     $180MM
# 261  $28MM      $180MM
# 262  $15MM      $180MM
# 263  $70MM      $179MM
# 264  $225MM     $179MM
# 265  $14MM      $178MM
# 266  $135MM     $177MM
# 267  $150MM     $177MM
# 268  $21MM      $177MM
# 269  $145MM     $177MM
# 270  $93MM      $177MM
# 271  $140MM     $177MM
# 272  $40MM      $177MM
# 273  $23MM      $176MM
# 274  $59MM      $176MM
# 275  $75MM      $176MM
# 276  $4.5MM     $176MM
# 277  $80MM      $176MM
# 278  $20MM      $175MM
# 279  $125MM     $175MM
# 280  $8.8MM     $175MM
# 281  $33MM      $175MM
# 282  $30MM      $175MM
# 283  $84MM      $174MM
# 284  $200MM     $174MM
# 285  $52MM      $174MM
# 286  $18MM      $174MM
# 287  $100MM     $173MM
# 288  $85MM      $173MM
# 289  $25MM      $173MM
# 290  $230MM     $173MM
# 291  $170MM     $172MM
# 292  $130MM     $172MM
# 293  $63MM      $171MM
# 294  $38MM      $171MM
# 295  $130MM     $171MM
# 296  $75MM      $171MM
# 297  $58MM      $171MM
# 298  $45MM      $171MM
# 299  $25MM      $170MM
# 300  $80MM      $170MM
# 301  $25MM      $170MM
# 302  $32MM      $169MM
# 303  $200MM     $168MM
# 304  NaN        $168MM
# 305  $185MM     $168MM
# 306  $11MM      $168MM
# 307  $61MM      $168MM
# 308  $80MM      $168MM
# 309  $150MM     $167MM
# 310  $55MM      $166MM
# 311  $40MM      $166MM
# 312  $200MM     $166MM
# 313  $48MM      $165MM
# 314  $40MM      $165MM
# 315  $150MM     $165MM
# 316  $87MM      $165MM
# 317  $52MM      $165MM
# 318  $40MM      $164MM
# 319  $55MM      $164MM
# 320  $34MM      $163MM
# 321  $125MM     $163MM
# 322  $74MM      $163MM
# 323  $80MM      $163MM
# 324  $100MM     $163MM
# 325  $120MM     $163MM
# 326  $120MM     $162MM
# 327  $80MM      $162MM
# 328  $23MM      $161MM
# 329  $95MM      $161MM
# 330  $28MM      $161MM
# 331  $142MM     $161MM
# 332  $75MM      $161MM
# 333  $129MM     $161MM
# 334  $43MM      $160MM
# 335  $200MM     $160MM
# 336  $10MM      $159MM
# 337  $8.2MM     $159MM
# 338  $100MM     $159MM
# 339  $80MM      $159MM
# 340  $185MM     $159MM
# 341  $42MM      $158MM
# 342  $82MM      $158MM
# 343  $75MM      $157MM
# 344  $19MM      $157MM
# 345  $14MM      $157MM
# 346  $70MM      $156MM
# 347  $5.5MM     $156MM
# 348  $100MM     $155MM
# 349  $178MM     $155MM
# 350  $80MM      $155MM
# 351  $170MM     $155MM
# 352  $110MM     $155MM
# 353  $85MM      $155MM
# 354  $80MM      $155MM
# 355  $100MM     $155MM
# 356  $85MM      $155MM
# 357  $150MM     $154MM
# 358  $50MM      $154MM
# 359  $125MM     $154MM
# 360  $28MM      $154MM
# 361  $84MM      $153MM
# 362  $11MM      $153MM
# 363  $175MM     $153MM
# 364  $65MM      $153MM
# 365  $70MM      $152MM
# 366  $30MM      $151MM
# 367  $85MM      $151MM
# 368  $44MM      $150MM
# 369  $37MM      $150MM
# 370  $200MM     $150MM
# 371  $50MM      $150MM
# 372  $175MM     $150MM
# 373  $18MM      $150MM
# 374  $40MM      $150MM
# 375  $130MM     $149MM
# 376  $61MM      $149MM
# 377  $30MM      $149MM
# 378  $50MM      $148MM
# 379  $100MM     $148MM
# 380  $130MM     $148MM
# 381  $85MM      $148MM
# 382  $72MM      $148MM
# 383  $33MM      $148MM
# 384  $28MM      $147MM
# 385  $150MM     $147MM
# 386  $160MM     $146MM
# 387  $26MM      $146MM
# 388  $115MM     $146MM
# 389  $80MM      $146MM
# 390  $130MM     $145MM
# 391  $30MM      $145MM
# 392  $25MM      $145MM
# 393  $4MM       $145MM
# 394  $105MM     $145MM
# 395  $22MM      $145MM
# 396  $120MM     $145MM
# 397  $35MM      $145MM
# 398  $38MM      $145MM
# 399  $52MM      $144MM
# 400  $72MM      $144MM
# 401  $150MM     $144MM
# 402  $90MM      $144MM
# 403  $145MM     $144MM
# 404  $7.5MM     $143MM
# 405  $60MM      $143MM
# 406  $110MM     $143MM
# 407  $90MM      $143MM
# 408  $70MM      $142MM
# 409  $4MM       $142MM
# 410  $225MM     $142MM
# 411  $3MM       $142MM
# 412  $55MM      $142MM
# 413  $41MM      $141MM
# 414  $15MM      $141MM
# 415  $33MM      $141MM
# 416  $60K       $141MM
# 417  $75MM      $140MM
# 418  $100MM     $140MM
# 419  $70MM      $140MM
# 420  $140MM     $140MM
# 421  $7.5MM     $140MM
# 422  $133MM     $140MM
# 423  $45MM      $140MM
# 424  $31MM      $140MM
# 425  $150MM     $139MM
# 426  $65MM      $139MM
# 427  $15MM      $139MM
# 428  $40MM      $139MM
# 429  $130MM     $139MM
# 430  $6MM       $139MM
# 431  $42MM      $138MM
# 432  $10MM      $138MM
# 433  $9MM       $138MM
# 434  $200MM     $138MM
# 435  $128MM     $138MM
# 436  $175MM     $138MM
# 437  $20MM      $137MM
# 438  $82MM      $137MM
# 439  $60MM      $137MM
# 440  $80MM      $136MM
# 441  $130MM     $136MM
# 442  $75MM      $136MM
# 443  $44MM      $136MM
# 444  $75MM      $136MM
# 445  $150MM     $135MM
# 446  $14MM      $135MM
# 447  $20MM      $135MM
# 448  $90MM      $135MM
# 449  $6MM       $135MM
# 450  $25MM      $135MM
# 451  $150MM     $135MM
# 452  $110MM     $135MM
# 453  $75MM      $135MM
# 454  $35MM      $135MM
# 455  $55MM      $134MM
# 456  $75MM      $134MM
# 457  $150MM     $134MM
# 458  $80MM      $134MM
# 459  $175MM     $133MM
# 460  $150MM     $133MM
# 461  $75MM      $133MM
# 462  $33MM      $133MM
# 463  $120MM     $133MM
# 464  $20MM      $132MM
# 465  $90MM      $132MM
# 466  $137MM     $132MM
# 467  $21MM      $132MM
# 468  $102MM     $132MM
# 469  $130MM     $132MM
# 470  $150MM     $132MM
# 471  $103MM     $132MM
# 472  $115MM     $131MM
# 473  $19MM      $131MM
# 474  $18MM      $131MM
# 475  $46MM      $131MM
# 476  $140MM     $130MM
# 477  $80MM      $130MM
# 478  $110MM     $130MM
# 479  $99MM      $130MM
# 480  $217MM     $130MM
# 481  $100MM     $130MM
# 482  $15MM      $130MM
# 483  $7.5MM     $130MM
# 484  $48MM      $129MM
# 485  $54MM      $129MM
# 486  $18MM      $129MM
# 487  $144MM     $128MM
# 488  $81MM      $128MM
# 489  $75MM      $128MM
# 490  $39MM      $128MM
# 491  $17MM      $128MM
# 492  $80MM      $128MM
# 493  $50MM      $128MM
# 494  $30MM      $128MM
# 495  $85MM      $128MM
# 496  $150MM     $128MM
# 497  $50MM      $127MM
# 498  $50MM      $127MM
# 499  $30MM      $127MM
#          imdb_id                              title  year            director  \
# 14697  tt8919764  BEW International Grand Prix 2018  2018  Declan Kellett
# 14698  tt1081935  Baarìa                             2009  Giuseppe Tornatore
# 14699  tt0109191  Babyfever                          1994  Victoria Foyt
# 14700  tt0168475  Babymother                         1998  Julian Henriques
# 14701  NaN        NaN                                NaN   NaN
#
#                   production_co region_code     rank budget_usd us_gross
# 14697  British Empire Wrestling  [US]        921,882  $9K        NaN
# 14698  Medusa Film               [IT]        29,257   €28MM      NaN
# 14699  Jagtoria Films            NaN         194,766  NaN        NaN
# 14700  Arts Council of England   [GB]        145,216  £2MM       NaN
# 14701  NaN                       NaN         NaN      NaN        NaN
# (14702, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14702 entries, 0 to 14701
# Data columns (total 9 columns):
# imdb_id          14700 non-null object
# title            14700 non-null object
# year             14685 non-null object
# director         14671 non-null object
# production_co    14345 non-null object
# region_code      13447 non-null object
# rank             14688 non-null object
# budget_usd       7996 non-null object
# us_gross         14598 non-null object
# dtypes: object(9)
# memory usage: 1.0+ MB
# 6232
# 6952

# %%
movie_gross_df.head()
movie_gross_df.tail(200)
# Out:
#                                          title studio  domestic_gross  \
# 0  Toy Story 3                                  BV     415000000.0
# 1  Alice in Wonderland (2010)                   BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1  WB     296000000.0
# 3  Inception                                    WB     292600000.0
# 4  Shrek Forever After                          P/DW   238700000.0
#
#   foreign_gross  year
# 0  652000000     2010
# 1  691300000     2010
# 2  664300000     2010
# 3  535700000     2010
# 4  513900000     2010
#                                                                    title  \
# 3187  Death Wish (2018)
# 3188  Nobody's Fool
# 3189  Bad Times At The El Royale
# 3190  Baaghi 2
# 3191  The Happytime Murders
# 3192  Midnight Sun
# 3193  Pad Man
# 3194  Monster Family
# 3195  White Boy Rick
# 3196  Winchester
# 3197  The Death of Stalin
# 3198  Strangers: Prey at Night
# 3199  Paul, Apostle of Christ
# 3200  Padmaavat
# 3201  Proud Mary
# 3202  Superfly
# 3203  If Beale Street Could Talk
# 3204  Burn the Stage: The Movie
# 3205  Detective K: Secret of the Living Dead
# 3206  The Wife
# 3207  Hell Fest
# 3208  Chappaquiddick
# 3209  They Shall Not Grow Old
# 3210  Free Solo
# 3211  The Children Act
# 3212  Beautiful Boy (2018)
# 3213  Hunter Killer
# 3214  Tully (2018)
# 3215  Unfriended: Dark Web
# 3216  Upgrade
# 3217  Unsane
# 3218  The Sisters Brothers
# 3219  Welcome to Marwen
# 3220  Hotel Artemis
# 3221  Marrowbone
# 3222  102 Not Out
# 3223  Boy Erased
# 3224  Back to Burgundy
# 3225  The Bookshop
# 3226  The Old Man & the Gun
# 3227  Gringo
# 3228  Golden Slumber
# 3229  Kin
# 3230  The Big Bad Fox and Other Tales
# 3231  Traffik
# 3232  Can You Ever Forgive Me?
# 3233  7 Days in Entebbe
# 3234  Pope Francis - A Man of His Word
# 3235  Condorito: La Pelicula
# 3236  Suspiria
# 3237  Disobedience
# 3238  Qué León (What A Lion)
# 3239  Life Itself (2018)
# 3240  Beirut
# 3241  Return of the Hero
# 3242  Soorma
# 3243  The Hurricane Heist
# 3244  Every Day (2018)
# 3245  Leave No Trace
# 3246  My Hero Academia: Two Heroes
# 3227  STX           5000000.0       6000000       2018
# 3228  CJ            94500.0         10600000      2018
# 3229  LGF           5700000.0       4300000       2018
# 3230  GK            35800.0         9600000       2018
# 3231  LGF           9200000.0       336000        2018
# 3232  FoxS          8800000.0       NaN           2018
# 3233  Focus         3300000.0       5400000       2018
# 3234  Focus         2000000.0       6600000       2018
# 3235  LGF           448000.0        8000000       2018
# 3236  Amazon        2500000.0       5400000       2018
# 3237  BST           3500000.0       4400000       2018
# 3238  Spanglish     2600000.0       5200000       2018
# 3239  Amazon        4099999.0       3700000       2018
# 3240  BST           5000000.0       2500000       2018
# 3241  Distrib.      37100.0         7300000       2018
# 3242  Sony          390000.0        6200000       2018
# 3243  ENTMP         6100000.0       NaN           2018
# 3244  Orion         6100000.0       NaN           2018
# 3245  BST           6000000.0       NaN           2018
# 3246  FUN           5800000.0       NaN           2018
# 3247  Annapurna     1500000.0       4000000       2018
# 3248  Blue Fox      91000.0         5300000       2018
# 3249  BST           5100000.0       NaN           2018
# 3250  LG/S          4300000.0       530000        2018
# 3251  Amazon        4600000.0       NaN           2018
# 3252  BST           2300000.0       2200000       2018
# 3253  VE            4300000.0       NaN           2018
# 3254  Scre.         29500.0         4200000       2018
# 3255  Yash          330000.0        3900000       2018
# 3256  PNT           4200000.0       NaN           2018
# 3257  Amazon        1400000.0       2500000       2018
# 3258  Aviron        1600000.0       2200000       2018
# 3259  RAtt.         3700000.0       NaN           2018
# 3260  Electric      3400000.0       NaN           2018
# 3261  Cohen         200000.0        3100000       2018
# 3262  Magn.         3300000.0       NaN           2018
# 3263  Sony          2000000.0       1200000       2018
# 3264  WB            3200000.0       NaN           2018
# 3265  IFC           1100000.0       2000000       2018
# 3266  PNT           2800000.0       NaN           2018
# 3267  Amazon        2500000.0       NaN           2018
# 3268  VE            1300.0          2500000       2018
# 3269  SPC           2400000.0       NaN           2018
# 3270  GK            2400000.0       NaN           2018
# 3271  VE            491000.0        1700000       2018
# 3272  SPC           2000000.0       NaN           2018
# 3273  Fathom        1900000.0       NaN           2018
# 3274  SPC           1700000.0       NaN           2018
# 3275  LGF           1400.0          1500000       2018
# 3276  RAtt.         1400000.0       NaN           2018
# 3277  SPC           1300000.0       NaN           2018
# 3278  SPC           1300000.0       NaN           2018
# 3279  RLJ           1200000.0       NaN           2018
# 3280  Eros          1200000.0       NaN           2018
# 3281  A24           1200000.0       NaN           2018
# 3282  Swen          1000000.0       NaN           2018
# 3283  Eros          1000000.0       NaN           2018
# 3284  Cohen         1000000.0       NaN           2018
# 3285  EOne          990000.0        NaN           2018
# 3286  IFC           725000.0        229000        2018
# 3287  FR            905000.0        NaN           2018
# 3288  PackYourBag   901000.0        NaN           2018
# 3289  Uni.          833000.0        NaN           2018
# 3290  GK            813000.0        NaN           2018
# 3291  RAtt.         800000.0        NaN           2018
# 3292  Fathom        789000.0        NaN           2018
# 3293  RAtt.         750000.0        NaN           2018
# 3294  WGUSA         719000.0        NaN           2018
# 3295  SPC           619000.0        NaN           2018
# 3296  Fathom        616000.0        NaN           2018
# 3297  Fathom        583000.0        NaN           2018
# 3298  Eros          567000.0        NaN           2018
# 3299  SPC           566000.0        NaN           2018
# 3300  Fathom        550000.0        NaN           2018
# 3301  GK            525000.0        NaN           2018
# 3302  CJ            501000.0        NaN           2018
# 3303  SPC           466000.0        NaN           2018
# 3304  SPC           462000.0        NaN           2018
# 3305  Gaum.         411000.0        NaN           2018
# 3306  Fathom        394000.0        NaN           2018
# 3307  FM            375000.0        NaN           2018
# 3308  Greenwich     365000.0        NaN           2018
# 3309  Grindstone    10000.0         256000        2018
# 3310  BST           260000.0        NaN           2018
# 3311  Eros          250000.0        NaN           2018
# 3312  Neon          231000.0        NaN           2018
# 3313  Abr.          231000.0        NaN           2018
# 3314  Fathom        221000.0        NaN           2018
# 3315  Fathom        194000.0        NaN           2018
# 3316  Osci.         186000.0        NaN           2018
# 3317  Elev.         186000.0        NaN           2018
# 3318  PackYourBag   182000.0        NaN           2018
# 3319  CL            181000.0        NaN           2018
# 3320  CJ            179000.0        NaN           2018
# 3321  MBox          177000.0        NaN           2018
# 3322  VPD           170000.0        NaN           2018
# 3323  Cohen         168000.0        NaN           2018
# 3324  IFC           149000.0        NaN           2018
# 3325  Vita.         149000.0        NaN           2018
# 3326  Conglomerate  147000.0        NaN           2018
# 3327  Orch.         126000.0        NaN           2018
# 3328  MBox          120000.0        NaN           2018
# 3329  MUBI          117000.0        NaN           2018
# 3330  WGUSA         115000.0        NaN           2018
# 3331  CJ            112000.0        NaN           2018
# 3332  Orch.         112000.0        NaN           2018
# 3333  CJ            111000.0        NaN           2018
# 3334  MBox          109000.0        NaN           2018
# 3335  IFC           109000.0        NaN           2018
# 3336  FM            108000.0        NaN           2018
# 3337  Eros          104000.0        NaN           2018
# 3338  Eros          103000.0        NaN           2018
# 3339  Magn.         103000.0        NaN           2018
# 3340  Neon          102000.0        NaN           2018
# 3341  WGUSA         101000.0        NaN           2018
# 3342  Darin Southa  93200.0         5200          2018
# 3343  FM            89300.0         NaN           2018
# 3344  IFC           88000.0         NaN           2018
# 3345  KL            83900.0         NaN           2018
# 3346  Cohen         82300.0         NaN           2018
# 3347  EOne          78000.0         NaN           2018
# 3348  Eros          75900.0         NaN           2018
# 3349  CJ            75100.0         NaN           2018
# 3350  KL            74800.0         NaN           2018
# 3351  OutF          73500.0         NaN           2018
# 3352  Magn.         73300.0         NaN           2018
# 3353  FM            43200.0         30000         2018
# 3354  Eros          72000.0         NaN           2018
# 3355  Magn.         67600.0         NaN           2018
# 3356  Super         52100.0         NaN           2018
# 3357  FM            50900.0         NaN           2018
# 3358  Super         46300.0         NaN           2018
# 3359  Cohen         44300.0         NaN           2018
# 3360  KL            44200.0         NaN           2018
# 3361  IFC           41900.0         NaN           2018
# 3362  CL            37700.0         NaN           2018
# 3363  WGUSA         37100.0         NaN           2018
# 3364  Distrib.      36400.0         NaN           2018
# 3365  MBox          28300.0         NaN           2018
# 3366  FM            26200.0         NaN           2018
# 3367  Scre.         24300.0         NaN           2018
# 3368  Strand        22100.0         NaN           2018
# 3369  Uni.          22000.0         NaN           2018
# 3370  KL            21600.0         NaN           2018
# 3371  CL            20700.0         NaN           2018
# 3372  Strand        18400.0         NaN           2018
# 3373  Icar.         17800.0         NaN           2018
# 3374  IFC           14000.0         NaN           2018
# 3375  CARUSEL       13000.0         NaN           2018
# 3376  CLS           12900.0         NaN           2018
# 3377  Men.          12200.0         NaN           2018
# 3378  PDF           11700.0         NaN           2018
# 3379  Strand        11400.0         NaN           2018
# 3380  CARUSEL       10000.0         NaN           2018
# 3381  Osci.         8900.0          NaN           2018
# 3382  Magn.         6200.0          NaN           2018
# 3383  FM            4800.0          NaN           2018
# 3384  Sony          2500.0          NaN           2018
# 3385  Synergetic    2400.0          NaN           2018
# 3386  Grav.         1700.0          NaN           2018

# %%
imdb_name_basics_df.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder NaN         NaN
# 1  nm0061865  Joseph Bauer      NaN         NaN
# 2  nm0062070  Bruce Baum        NaN         NaN
# 3  nm0062195  Axel Baumann      NaN         NaN
# 4  nm0062798  Pete Baxter       NaN         NaN
#
#                                  primary_profession  \
# 0  miscellaneous,production_manager,producer
# 1  composer,music_department,sound_department
# 2  miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
imdb_title_akas_df.head()

# %%
imdb_title_basics_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540  Sunghursh                        Sunghursh
# 1  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din
# 2  tt0069049  The Other Side of the Wind       The Other Side of the Wind
# 3  tt0069204  Sabse Bada Sukh                  Sabse Bada Sukh
# 4  tt0100275  The Wandering Soap Opera         La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0  2013        175.0            Action,Crime,Drama
# 1  2019        114.0            Biography,Drama
# 2  2018        122.0            Drama
# 3  2018       NaN               Comedy,Drama
# 4  2017        80.0             Comedy,Drama,Fantasy

# %%
imdb_title_crew_df.head()

# %%
imdb_title_principals_df.head()

# %%
imdb_title_ratings_df.head()

# %%
tmdb_movies_df.head()

# %%
movie_budgets_df.head()
movie_budgets_df.tail(200)

# %% [markdown]
# ## Check shapes and info

# %%
## Check shapes ##
print(f'Shape of movie_gross_df is {movie_gross_df.shape}')
print(f'Shape of imdb_name_basics_df is {imdb_name_basics_df.shape}')
print(f'Shape of imdb_title_akas is {imdb_title_akas_df.shape}')
print(f'Shape of imdb_title_basics_df  is {imdb_title_basics_df .shape}')
print(f'Shape of imdb_title_crew_df is {imdb_title_crew_df.shape}')
print(f'Shape of imdb_title_principals_df is {imdb_title_principals_df.shape}')
print(f'Shape of imdb_title_ratings_df is {imdb_title_ratings_df.shape}')
print(f'Shape of tmdb_movies_df is {tmdb_movies_df.shape}')
print(f'Shape of movie_budgets_df is {movie_budgets_df.shape}')

# %%
## Check info ##
print('----------------movie_gross_df--------------------')
movie_gross_df.info()
print('----------------imdb_name_basics_df--------------------')
imdb_name_basics_df.info()
print('----------------imdb_title_akas_df--------------------')
imdb_title_akas_df.info()
print('----------------imdb_title_basics_df--------------------')
imdb_title_basics_df.info()
print('----------------imdb_title_crew_df-------------------')
imdb_title_crew_df.info()
print('----------------imdb_title_principals_df--------------------')
imdb_title_principals_df.info()
print('----------------imdb_title_ratings_df--------------------')
imdb_title_ratings_df.info()
print('----------------tmdb_movies_df--------------------')
tmdb_movies_df.info() 
print('----------------movie_budgets_df--------------------')
movie_budgets_df.info()

# %%
## Check invalid (nan) values ##
movie_gross_df.isna().sum()
imdb_name_basics_df.isna().sum()
imdb_title_akas_df.isna().sum()
imdb_title_basics_df.isna().sum()
imdb_title_crew_df.isna().sum()
imdb_title_principals_df.isna().sum()
imdb_title_ratings_df.isna().sum()
tmdb_movies_df.isna().sum()
movie_budgets_df.isna().sum()

# %% [markdown]
# ## Data cleaning for movie_gross_df

# %%
movie_gross_df.head()
movie_gross_df.tail()
movie_gross_df.info()
# Out:
#                                          title studio  domestic_gross  \
# 0  Toy Story 3                                  BV     415000000.0
# 1  Alice in Wonderland (2010)                   BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1  WB     296000000.0
# 3  Inception                                    WB     292600000.0
# 4  Shrek Forever After                          P/DW   238700000.0
#
#   foreign_gross  year
# 0  652000000     2010
# 1  691300000     2010
# 2  664300000     2010
# 3  535700000     2010
# 4  513900000     2010
#                             title      studio  domestic_gross foreign_gross  \
# 3382  The Quake                    Magn.       6200.0          NaN
# 3383  Edward II (2018 re-release)  FM          4800.0          NaN
# 3384  El Pacto                     Sony        2500.0          NaN
# 3385  The Swan                     Synergetic  2400.0          NaN
# 3386  An Actor Prepares            Grav.       1700.0          NaN
#
#       year
# 3382  2018
# 3383  2018
# 3384  2018
# 3385  2018
# 3386  2018
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
movie_gross_df = movie_gross_df.dropna()

# %%
# [float(a) for a in movie_gross_df['foreign_gross']]
# for i, row in movie_gross_df.iterrows():
#     if not isinstance(row['foreign_gross'], str):
#         print(i, row['foreign_gross'])

# %%
movie_gross_df[movie_gross_df['foreign_gross'] == "1,131.6"]
# Out:
#                              title studio  domestic_gross foreign_gross  year
# 1872  Star Wars: The Force Awakens  BV     936700000.0     1,131.6       2015

# %%
movie_gross_df[movie_gross_df['foreign_gross'] == "1,131.6"].index
# Out:
# Int64Index([1872], dtype='int64')

# %%
movie_gross_df['foreign_gross'] = movie_gross_df['foreign_gross'].apply(lambda x: x.replace(',',''))
movie_gross_df['foreign_gross'] = movie_gross_df['foreign_gross'].apply(lambda x: x.replace('.',''))

# %%
movie_gross_df['foreign_gross'] = movie_gross_df['foreign_gross'].astype(float)

# %%
# movie_gross_df.info()

# %%
sum_column = movie_gross_df['foreign_gross'] + movie_gross_df['domestic_gross']
movie_gross_df["total_gross"] = sum_column

# %%
# movie_gross_df.head(100)

# %%
# movie_gross_df = movie_gross_df.sort_values(by='total_gross', ascending = False) #bu olmasa da olur mu?

# %%
grouped_movie_gross_df = movie_gross_df.groupby('studio', as_index=False).mean().sort_values(by = 'total_gross', ascending = False)

# %%
# grouped_movie_gross_df.head()

# %%
filtered_grouped_movie_gross_df = grouped_movie_gross_df[grouped_movie_gross_df['total_gross']>1e7]

# %%
# len(filtered_grouped_movie_gross_df)
# len(grouped_movie_gross_df)

# %%
# filtered_grouped_movie_gross_df = grouped_movie_gross_df['studio'].apply(lambda x: x.sort_values())
#bunu silebilirim

# %%
grouped_movie_gross_df.head()
# Out:
#        studio  domestic_gross  foreign_gross         year   total_gross
# 67   HC        2.700000e+06    8.676000e+08   2017.000000  8.703000e+08
# 116  P/DW      1.682900e+08    3.393600e+08   2010.900000  5.076500e+08
# 22   BV        1.768897e+08    2.480181e+08   2013.730769  4.249078e+08
# 66   GrtIndia  2.020000e+07    2.340000e+08   2017.000000  2.542000e+08
# 163  WB        9.325846e+07    1.435993e+08   2013.853846  2.368577e+08

# %% [markdown]
# ## Plot the high budget studios

# %%
sns.set(rc={'figure.figsize':(35,8.27)})
sns.barplot(x="studio", y="total_gross", data=filtered_grouped_movie_gross_df)

# %% [markdown]
# # title akas i kullanmadim

# %%
# imdb_title_akas_df.head(110)

# imdb_title_akas_df = imdb_title_akas_df[pd.notnull(imdb_title_akas_df['region'])]

# imdb_title_akas_df = imdb_title_akas_df.drop(imdb_title_akas_df['region'!= 'US'].index)

# test = pd.DataFrame({'x': np.random.randn(int(1e6))})
# test = test.drop(test[test.x > 0].index)

# imdb_title_akas_df= imdb_title_akas_df[(imdb_title_akas_df['region'] =='US' ).all(axis=0)]

# %%
# imdb_title_akas_df.head(110)

# %%
# type(imdb_title_akas_df['region'][80])

# %% [markdown]
# ## Data cleaning for imdb_title_basics_df

# %%
imdb_title_basics_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540  Sunghursh                        Sunghursh
# 1  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din
# 2  tt0069049  The Other Side of the Wind       The Other Side of the Wind
# 3  tt0069204  Sabse Bada Sukh                  Sabse Bada Sukh
# 4  tt0100275  The Wandering Soap Opera         La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0  2013        175.0            Action,Crime,Drama
# 1  2019        114.0            Biography,Drama
# 2  2018        122.0            Drama
# 3  2018       NaN               Comedy,Drama
# 4  2017        80.0             Comedy,Drama,Fantasy

# %%
# len(imdb_title_basics_df)

# %%
imdb_title_basics_df['tconst'].isna().sum()
imdb_title_basics_df['primary_title'].isna().sum()
imdb_title_basics_df['original_title'].isna().sum()
imdb_title_basics_df['start_year'].isna().sum()
imdb_title_basics_df['runtime_minutes'].isna().sum()
imdb_title_basics_df['genres'].isna().sum()
# Out:
# 0
# 0
# 21
# 0
# 31739
# 5408

# %%
imdb_title_basics_df['genres'].dropna(inplace = True)

# %%
# len(imdb_title_basics_df.genres)

# %%
# len(imdb_title_basics_df)

# %%
movie_budgets_df['genres'] = movie_budgets_df['genres'].apply(lambda x: x.replace(',',''))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genres'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-5793e977a5c0> in <module>
# ----> 1 movie_budgets_df['genres'] = movie_budgets_df['genres'].apply(lambda x: x.replace(',',''))
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genres'

# %%
movie_budgets_df["genres"]= movie_budgets_df["genres"].str.split(",", 3)

# %%
movie_budgets_df=movie_budgets_df.explode('genres')

# %%
movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0  1   Dec 18, 2009  Avatar
# 1  2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1  2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1  2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2  3   Jun 7, 2019   Dark Phoenix
#
#   production_budget domestic_gross worldwide_gross     tconst  \
# 0  $425,000,000      $760,507,625   $2,776,345,279  tt1775309
# 1  $410,600,000      $241,063,875   $1,045,663,875  tt1298650
# 1  $410,600,000      $241,063,875   $1,045,663,875  tt1298650
# 1  $410,600,000      $241,063,875   $1,045,663,875  tt1298650
# 2  $350,000,000      $42,762,350    $149,762,350    tt6565702
#
#                                 original_title  start_year  runtime_minutes  \
# 0  Abatâ                                        2011        93.0
# 1  Pirates of the Caribbean: On Stranger Tides  2011        136.0
# 1  Pirates of the Caribbean: On Stranger Tides  2011        136.0
# 1  Pirates of the Caribbean: On Stranger Tides  2011        136.0
# 2  Dark Phoenix                                 2019        113.0
#
#       genres
# 0  Horror
# 1  Action
# 1  Adventure
# 1  Fantasy
# 2  Action

# %%
# imdb_title_basics_df.dropna(inplace = True)

# %%
# imdb_title_basics_df['genres'].nunique()

# %%
imdb_title_basics_df=imdb_title_basics_df.drop_duplicates(subset='primary_title', keep='first')

# %%
len(imdb_title_basics_df)

# %%
# imdb_title_basics_df["genres"]= imdb_title_basics_df["genres"].str.split(",", 3)

# %%
# imdb_title_basics_df.head()

# %%
imdb_title_basics_df = imdb_title_basics_df.rename(columns={'primary_title': 'movie'})

# %%
# imdb_title_basics_df.head()

# %%
# type(imdb_title_basics_df['genres'][0])

# %%
movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0  1   Dec 18, 2009  Avatar
# 1  2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2  3   Jun 7, 2019   Dark Phoenix
# 3  4   May 1, 2015   Avengers: Age of Ultron
# 4  7   Apr 27, 2018  Avengers: Infinity War
#
#   production_budget domestic_gross worldwide_gross     tconst  \
# 0  $425,000,000      $760,507,625   $2,776,345,279  tt1775309
# 1  $410,600,000      $241,063,875   $1,045,663,875  tt1298650
# 2  $350,000,000      $42,762,350    $149,762,350    tt6565702
# 3  $330,600,000      $459,005,868   $1,403,013,963  tt2395427
# 4  $300,000,000      $678,815,482   $2,048,134,200  tt4154756
#
#                                 original_title  start_year  runtime_minutes  \
# 0  Abatâ                                        2011        93.0
# 1  Pirates of the Caribbean: On Stranger Tides  2011        136.0
# 2  Dark Phoenix                                 2019        113.0
# 3  Avengers: Age of Ultron                      2015        141.0
# 4  Avengers: Infinity War                       2018        149.0
#
#                      genres
# 0  Horror
# 1  Action,Adventure,Fantasy
# 2  Action,Adventure,Sci-Fi
# 3  Action,Adventure,Sci-Fi
# 4  Action,Adventure,Sci-Fi

# %% [markdown]
# ## Merging two dataframes

# %%
movie_budgets_df = pd.merge(movie_budgets_df, imdb_title_basics_df, how='inner', on='movie')

# %%
movie_budgets_df.tail()

# %% [markdown]
# # daha dikkatli dropna yap

# %%
len(movie_budgets_df)

# %%
#dropping null values from 'genres' column and 'runtime minutes' column
# movie_budgets_df = movie_budgets_df.dropna(subset=['genres','runtime_minutes','worldwide_gross'])

# %%
movie_budgets_df = movie_budgets_df.reset_index()

# %%
movie_budgets_df = movie_budgets_df.drop(columns = ['index'])

# %%
movie_budgets_df.head()

# %%
# movie_budgets_df = movie_budgets_df.drop_duplicates(subset="movie", keep="first")

# %%
len(movie_budgets_df)

# %%
movie_budgets_df = movie_budgets_df.sort_values(by='worldwide_gross')

# %%
movie_budgets_df.head(500)

# %%
movie_budgets_df=movie_budgets_df.reset_index()
movie_budgets_df=movie_budgets_df[200:]

# %%
movie_budgets_df.head()

# %%
len(movie_budgets_df)

# %% [markdown]
# ## Plot the genres of movies

# %%
# type(movie_budgets_df['worldwide_gross'][250])

# %%
# movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].apply(lambda x: x.replace(',',''))
# movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].apply(lambda x: x.replace('.',''))

# movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].apply(lambda x: x.replace('$',''))

# %%
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].astype(int)

# %%
movie_budgets_df = movie_budgets_df.sort_values(by='worldwide_gross')

# %%
movie_budgets_df.head(200)
movie_budgets_df.tail()

# %%
sns.catplot(x="genres", y="runtime_minutes",  kind="bar", data=movie_budgets_df)

# %%
# fig_dims = (35, 9)
# fig, ax = plt.subplots(figsize=fig_dims)
# # sns.set(style="whitegrid")
# sns.catplot(x = "genres", y = "runtime_minutes",data=movie_budgets_df)



# movie_budgets_df = movie_budgets_df.groupby('genres').sum()
# movie_budgets_df.reset_index(inplace=True)
# Yukaridaki islemler datayi degistirmis olabilir, grafik problemli

sns.catplot(x = "genres", y = "runtime_minutes",data=movie_budgets_df,height=5,aspect=3,kind='bar')

# %%
# sns.set(rc={'figure.figsize':(35,8.27)})
# plt.figure(figsize=(15,4))

sns.catplot(x="genres", y="worldwide_gross", data=movie_budgets_df, kind="bar",height=5,aspect=3 )

# %% [markdown]
# ## Plot the budget and gross

# %%
movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].apply(lambda x: x.strip('$'))
movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].apply(lambda x: x.replace(',',''))
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].apply(lambda x: x.strip('$'))
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].apply(lambda x: x.replace(',',''))

# %%
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].apply(lambda x: x.strip('$'))
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].apply(lambda x: x.replace(',',''))

# %%
movie_budgets_df.head()

# %%
movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].astype(float)
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].astype(float)

# %%
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].astype(float)

# %%
type(movie_budgets_df['production_budget'][0])

# %%
movie_budgets_df['release_month'] = [a[0:3] for a in movie_budgets_df['release_date']]

# %%
movie_budgets_df.head()

# %%
sns.lmplot(x="production_budget", y="worldwide_gross",hue= 'release_month', data=movie_budgets_df, scatter_kws={'alpha': 0.4},height=5,aspect=1)
plt.xlim([-0.5e8, None])
plt.ylim([-0.3e9, None])

# %%
sns.lmplot(x="production_budget", y="domestic_gross", hue= 'release_month', data=movie_budgets_df, scatter_kws={'alpha': 0.4})
plt.xlim([-0.5e8, None])
plt.ylim([-0.3e9, None])

# %%
Joining 'imdb.title.basics.csv' with 'tn.movie_budgets.csv'
In [8]:
movie_budgets.set_index('movie', inplace=True)
In [9]:
title_basics.rename(columns={'primary_title': 'movie'}, inplace=True)
In [10]:
title_basics.set_index('movie', inplace=True)
In [11]:
df_combine = movie_budgets.join(title_basics, how="inner")
df_combine.reset_index(inplace=True)
