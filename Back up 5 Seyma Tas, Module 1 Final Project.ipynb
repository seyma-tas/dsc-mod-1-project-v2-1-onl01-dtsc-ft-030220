# %% [markdown]
# # Final Project
#
# Please fill out:
# * Student name: Seyma Tas
# * Student pace: full time
# * Scheduled project review date/time:
# * Instructor name: Amber Yandow
# * Blog post URL:

# %%
# %autosave 10
# Autosaving every ten seconds.
# Out:
# Autosaving every 10 seconds

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
sns.set(color_codes=True)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Print all the interactive output without resorting to print

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Set options

# %%
## Display more information 

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Read datasets

# %%
## Instantiate data frame from data

movie_gross_df = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
imdb_name_basics_df = pd.read_csv ('zippedData/imdb.name.basics.csv.gz')
imdb_title_akas_df = pd.read_csv('zippedData/imdb.title.akas.csv.gz')
## I am not loading movie_info_df because I found movies_df which has more movies.
# imdb_title_basics_df = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
imdb_title_crew_df = pd.read_csv('zippedData/imdb.title.crew.csv.gz')
imdb_title_principals_df = pd.read_csv('zippedData/imdb.title.principals.csv.gz')
imdb_title_ratings_df = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
## I am not loading movie_info_df because I decided to not use the unique info (synopsis) from this table in my project
# movie_info_df = pd.read_csv('zippedData/rt.movie_info.tsv.gz', delimiter='\t') 
## I am not loading reviews_df because I decided to not use the unique info (review) from this table in my project
# reviews_df = pd.read_csv('zippedData/rt.reviews.tsv.gz', encoding= 'unicode_escape', delimiter = '\t')
tmdb_movies_df = pd.read_csv('zippedData/tmdb.movies.csv')
movie_budgets_df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
money_df = pd.read_csv('zippedData/money.csv')
movies_df = pd.read_csv('zippedData/movies.csv')

# %%
movies_df.head()
# Out:
#       tconst                   primaryTitle startYear                  genres
# 0  tt0000009  Miss Jerry                     1894      Romance
# 1  tt0000147  The Corbett-Fitzsimmons Fight  1897      Documentary,News,Sport
# 2  tt0000335  Soldiers of the Cross          1900      Biography,Drama
# 3  tt0000502  Bohemios                       1905      \N
# 4  tt0000574  The Story of the Kelly Gang    1906      Biography,Crime,Drama

# %%
movie_gross_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0  Toy Story 3                                  BV     415000000.0
# 1  Alice in Wonderland (2010)                   BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1  WB     296000000.0
# 3  Inception                                    WB     292600000.0
# 4  Shrek Forever After                          P/DW   238700000.0
#
#   foreign_gross  year
# 0  652000000     2010
# 1  691300000     2010
# 2  664300000     2010
# 3  535700000     2010
# 4  513900000     2010

# %%
movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0  1   Dec 18, 2009  Avatar
# 1  2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2  3   Jun 7, 2019   Dark Phoenix
# 3  4   May 1, 2015   Avengers: Age of Ultron
# 4  5   Dec 15, 2017  Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0  $425,000,000      $760,507,625   $2,776,345,279
# 1  $410,600,000      $241,063,875   $1,045,663,875
# 2  $350,000,000      $42,762,350    $149,762,350
# 3  $330,600,000      $459,005,868   $1,403,013,963
# 4  $317,000,000      $620,181,382   $1,316,721,747

# %%
money_df.head()
# Out:
#      imdb_id                                       title  year       director  \
# 0  tt2488496  Star Wars: Episode VII - The Force Awakens  2015  J.J. Abrams
# 1  tt4154796  Avengers: Endgame                           2019  Anthony Russo
# 2  tt0499549  Avatar                                      2009  James Cameron
# 3  tt1825683  Black Panther                               2018  Ryan Coogler
# 4  tt4154756  Avengers: Infinity War                      2018  Anthony Russo
#
#            production_co region_code rank budget_usd us_gross
# 0  Lucasfilm              [US]        519  $245MM     $937MM
# 1  Marvel Studios         [US]        111  $356MM     $858MM
# 2  Twentieth Century Fox  [US]        533  $237MM     $761MM
# 3  Marvel Studios         [US]        269  $200MM     $700MM
# 4  Marvel Studios         [US]        376  $321MM     $679MM

# %% [markdown]
# ## Check shapes and info

# %%
## Check shapes ##
print(f'Shape of movie_gross_df is {movie_gross_df.shape}')
print(f'Shape of imdb_name_basics_df is {imdb_name_basics_df.shape}')
print(f'Shape of imdb_title_akas is {imdb_title_akas_df.shape}')
print(f'Shape of imdb_title_crew_df is {imdb_title_crew_df.shape}')
print(f'Shape of imdb_title_principals_df is {imdb_title_principals_df.shape}')
print(f'Shape of imdb_title_ratings_df is {imdb_title_ratings_df.shape}')
print(f'Shape of tmdb_movies_df is {tmdb_movies_df.shape}')
print(f'Shape of movie_budgets_df is {movie_budgets_df.shape}')
print(f'Shape of money_df is {money_df.shape}')
print(f'Shape of movies_df is {movies_df.shape}')
# Out:
# Shape of movie_gross_df is (3387, 5)
# Shape of imdb_name_basics_df is (606648, 6)
# Shape of imdb_title_akas is (331703, 8)
# Shape of imdb_title_crew_df is (146144, 3)
# Shape of imdb_title_principals_df is (1028186, 6)
# Shape of imdb_title_ratings_df is (73856, 3)
# Shape of tmdb_movies_df is (26517, 10)
# Shape of movie_budgets_df is (5782, 6)
# Shape of money_df is (14702, 9)
# Shape of movies_df is (545821, 4)

# %%
## Check info ##
print('----------------movie_gross_df--------------------')
movie_gross_df.info()
print('----------------imdb_name_basics_df--------------------')
imdb_name_basics_df.info()
print('----------------imdb_title_akas_df--------------------')
imdb_title_akas_df.info()
print('----------------imdb_title_crew_df-------------------')
imdb_title_crew_df.info()
print('----------------imdb_title_principals_df--------------------')
imdb_title_principals_df.info()
print('----------------imdb_title_ratings_df--------------------')
imdb_title_ratings_df.info()
print('----------------tmdb_movies_df--------------------')
tmdb_movies_df.info() 
print('----------------movie_budgets_df--------------------')
movie_budgets_df.info()
# Out:
# ----------------movie_gross_df--------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB
# ----------------imdb_name_basics_df--------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
# nconst                606648 non-null object
# primary_name          606648 non-null object
# birth_year            82736 non-null float64
# death_year            6783 non-null float64
# primary_profession    555308 non-null object
# known_for_titles      576444 non-null object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB
# ----------------imdb_title_akas_df--------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
# title_id             331703 non-null object
# ordering             331703 non-null int64
# title                331703 non-null object
# region               278410 non-null object
# language             41715 non-null object
# types                168447 non-null object
# attributes           14925 non-null object
# is_original_title    331678 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB
# ----------------imdb_title_crew_df-------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
# tconst       146144 non-null object
# directors    140417 non-null object
# writers      110261 non-null object
# dtypes: object(3)
# memory usage: 3.3+ MB
# ----------------imdb_title_principals_df--------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
# tconst        1028186 non-null object
# ordering      1028186 non-null int64
# nconst        1028186 non-null object
# category      1028186 non-null object
# job           177684 non-null object
# characters    393360 non-null object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB
# ----------------imdb_title_ratings_df--------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# ----------------tmdb_movies_df--------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
# Unnamed: 0           26517 non-null int64
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB
# ----------------movie_budgets_df--------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
## Check invalid (nan) values ##
movies_df.isna().sum()
movie_gross_df.isna().sum()
movie_budgets_df.isna().sum()
money_df.isna().sum()
# Out:
# tconst          0
# primaryTitle    0
# startYear       0
# genres          0
# dtype: int64
# title             0
# studio            5
# domestic_gross    28
# foreign_gross     1350
# year              0
# dtype: int64
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64
# imdb_id          2
# title            2
# year             17
# director         31
# production_co    357
# region_code      1255
# rank             14
# budget_usd       6706
# us_gross         104
# dtype: int64

# %% [markdown]
# ## Data cleaning for movie_gross_df

# %%
domestic_gross_df = movie_gross_df.dropna(subset = ['studio', 'domestic_gross'])
total_gross_df= movie_gross_df.dropna()

# %%
# [float(a) for a in movie_gross_df['foreign_gross']]
# for i, row in movie_gross_df.iterrows():
#     if not isinstance(row['foreign_gross'], str):
#         print(i, row['foreign_gross'])

# %%
total_gross_df[total_gross_df['foreign_gross'] == "1,131.6"]
# Out:
#                              title studio  domestic_gross foreign_gross  year
# 1872  Star Wars: The Force Awakens  BV     936700000.0     1,131.6       2015

# %%
total_gross_df[total_gross_df['foreign_gross'] == "1,131.6"].index
# Out:
# Int64Index([1872], dtype='int64')

# %%
total_gross_df['foreign_gross'] = total_gross_df['foreign_gross'].apply(lambda x: x.replace(',',''))
total_gross_df['foreign_gross'] = total_gross_df['foreign_gross'].apply(lambda x: x.replace('.',''))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
total_gross_df['foreign_gross'] = total_gross_df['foreign_gross'].astype(float)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# total_gross_df.info()

# %%
sum_column = total_gross_df['foreign_gross'] + total_gross_df['domestic_gross']
total_gross_df["total_gross"] = sum_column
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
total_gross_df = total_gross_df.sort_values(by='total_gross', ascending = False)

# %%
grouped_total_gross_df = total_gross_df.groupby('studio', as_index=False).mean().sort_values(by = 'total_gross', ascending = False)

# %%
filtered_grouped_total_gross_df = grouped_total_gross_df[grouped_total_gross_df['total_gross']>5e7]

# %%
# grouped_total_gross_df.head()
# filtered_grouped_total_gross_df.head()

# %%
grouped_domestic_gross_df = domestic_gross_df.groupby('studio', as_index=False).mean().sort_values(by = 'domestic_gross', ascending = False)

# %%
filtered_grouped_domestic_gross_df = grouped_domestic_gross_df[grouped_domestic_gross_df['domestic_gross']>1e7]

# %%
total_gross_df = total_gross_df[:800]

# %% [markdown]
# ## Plot the high profit studios

# %%
## Bar graph of high profit studios (domestic gross + foreign gross)
sns.set(rc={'figure.figsize':(35,8.27)})
sns.set(font_scale=2)
g=sns.barplot(x="studio", y="total_gross", data=total_gross_df)
for item in g.get_xticklabels():
    item.set_rotation(45)

# %%
## Bar graph of high profit studios (domestic gross + foreign gross)
sns.set(rc={'figure.figsize':(35,8.27)})
sns.set(font_scale=2)
g=sns.barplot(x="studio", y="total_gross", data=filtered_grouped_total_gross_df)
for item in g.get_xticklabels():
    item.set_rotation(45)

# %%
## Bar graph of high profit studios (domestic gross)
sns.set(rc={'figure.figsize':(35,8.27)})
sns.set(font_scale=2)
g=sns.barplot(x="studio", y="domestic_gross", data=filtered_grouped_domestic_gross_df)
for item in g.get_xticklabels():
    item.set_rotation(45)

# %% [markdown]
# ## Data cleaning for movies_df

# %%
movies_df['tconst'].isna().sum()
movies_df['primaryTitle'].isna().sum()
movies_df['startYear'].isna().sum()
movies_df['genres'].isna().sum()
# Out:
# 0
# 0
# 0
# 0

# %% [markdown]
# # Sor

# %%
# movies_df[movies_df.genres != ''\N''']

# %%
movies_df=movies_df.drop_duplicates(subset='tconst', keep='first')

# %% [markdown]
# ## Data cleaning for movie_budgets_df

# %%
movie_budgets_df.isna().sum()
## There is no need to drop columns.
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
## I did not drop the duplicates because there were different movies with the same name.

# movie_budgets_df = movie_budgets_df.drop_duplicates(subset="id", keep="first")

# %% [markdown]
# ## Merging two dataframes

# %%
movies_df = movies_df.rename(columns={'primaryTitle': 'movie'})

# %%
movie_budgets_df = pd.merge(movie_budgets_df, movies_df, how='inner', on='movie')

# %%
# movie_budgets_df['genres'] = movie_budgets_df['genres'].apply(lambda x: x.replace(',',''))

# %%
movie_budgets_df["genres"]= movie_budgets_df["genres"].str.split(",", 3)

# %%
movie_budgets_df=movie_budgets_df.explode('genres')

# %%
movie_budgets_df.head(100)
# Out:
#     id  release_date                                             movie  \
# 0   1   Dec 18, 2009  Avatar
# 1   1   Dec 18, 2009  Avatar
# 2   1   Dec 18, 2009  Avatar
# 2   1   Dec 18, 2009  Avatar
# 2   1   Dec 18, 2009  Avatar
# 3   1   Dec 18, 2009  Avatar
# 4   2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 4   2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 4   2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 5   4   May 1, 2015   Avengers: Age of Ultron
# 5   4   May 1, 2015   Avengers: Age of Ultron
# 5   4   May 1, 2015   Avengers: Age of Ultron
# 6   7   Apr 27, 2018  Avengers: Infinity War
# 6   7   Apr 27, 2018  Avengers: Infinity War
# 6   7   Apr 27, 2018  Avengers: Infinity War
# 7   9   Nov 17, 2017  Justice League
# 7   9   Nov 17, 2017  Justice League
# 7   9   Nov 17, 2017  Justice League
# 8   10  Nov 6, 2015   Spectre
# 9   10  Nov 6, 2015   Spectre
# 9   10  Nov 6, 2015   Spectre
# 9   10  Nov 6, 2015   Spectre
# 10  11  Jul 20, 2012  The Dark Knight Rises
# 10  11  Jul 20, 2012  The Dark Knight Rises
# 11  12  May 25, 2018  Solo: A Star Wars Story
# 11  12  May 25, 2018  Solo: A Star Wars Story
# 11  12  May 25, 2018  Solo: A Star Wars Story
# 12  13  Jul 2, 2013   The Lone Ranger
# 13  13  Jul 2, 2013   The Lone Ranger
# 13  13  Jul 2, 2013   The Lone Ranger
# 13  13  Jul 2, 2013   The Lone Ranger
# 14  13  Jul 2, 2013   The Lone Ranger
# 14  13  Jul 2, 2013   The Lone Ranger
# 14  13  Jul 2, 2013   The Lone Ranger
# 15  14  Mar 9, 2012   John Carter
# 15  14  Mar 9, 2012   John Carter
# 15  14  Mar 9, 2012   John Carter
# 16  15  Nov 24, 2010  Tangled
# 17  15  Nov 24, 2010  Tangled
# 17  15  Nov 24, 2010  Tangled
# 18  15  Nov 24, 2010  Tangled
# 18  15  Nov 24, 2010  Tangled
# 18  15  Nov 24, 2010  Tangled
#
#    production_budget domestic_gross worldwide_gross     tconst startYear  \
# 0   $425,000,000      $760,507,625   $2,776,345,279  tt0154182  1941
# 1   $425,000,000      $760,507,625   $2,776,345,279  tt0278325  1916
# 2   $425,000,000      $760,507,625   $2,776,345,279  tt0499549  2009
# 2   $425,000,000      $760,507,625   $2,776,345,279  tt0499549  2009
# 2   $425,000,000      $760,507,625   $2,776,345,279  tt0499549  2009
# 3   $425,000,000      $760,507,625   $2,776,345,279  tt1775309  2011
# 4   $410,600,000      $241,063,875   $1,045,663,875  tt1298650  2011
# 4   $410,600,000      $241,063,875   $1,045,663,875  tt1298650  2011
# 4   $410,600,000      $241,063,875   $1,045,663,875  tt1298650  2011
# 5   $330,600,000      $459,005,868   $1,403,013,963  tt2395427  2015
# 5   $330,600,000      $459,005,868   $1,403,013,963  tt2395427  2015
# 5   $330,600,000      $459,005,868   $1,403,013,963  tt2395427  2015
# 6   $300,000,000      $678,815,482   $2,048,134,200  tt4154756  2018
# 6   $300,000,000      $678,815,482   $2,048,134,200  tt4154756  2018
# 6   $300,000,000      $678,815,482   $2,048,134,200  tt4154756  2018
# 7   $300,000,000      $229,024,295   $655,945,209    tt0974015  2017
# 7   $300,000,000      $229,024,295   $655,945,209    tt0974015  2017
# 7   $300,000,000      $229,024,295   $655,945,209    tt0974015  2017
# 8   $300,000,000      $200,074,175   $879,620,923    tt1928272  \N
# 9   $300,000,000      $200,074,175   $879,620,923    tt2379713  2015
# 9   $300,000,000      $200,074,175   $879,620,923    tt2379713  2015
# 9   $300,000,000      $200,074,175   $879,620,923    tt2379713  2015
# 10  $275,000,000      $448,139,099   $1,084,439,099  tt1345836  2012
# 10  $275,000,000      $448,139,099   $1,084,439,099  tt1345836  2012
# 11  $275,000,000      $213,767,512   $393,151,347    tt3778644  2018
# 11  $275,000,000      $213,767,512   $393,151,347    tt3778644  2018
# 11  $275,000,000      $213,767,512   $393,151,347    tt3778644  2018
# 12  $275,000,000      $89,302,115    $260,002,115    tt0030382  1938
# 13  $275,000,000      $89,302,115    $260,002,115    tt0048310  1956
# 13  $275,000,000      $89,302,115    $260,002,115    tt0048310  1956
# 13  $275,000,000      $89,302,115    $260,002,115    tt0048310  1956
# 14  $275,000,000      $89,302,115    $260,002,115    tt1210819  2013
# 14  $275,000,000      $89,302,115    $260,002,115    tt1210819  2013
# 14  $275,000,000      $89,302,115    $260,002,115    tt1210819  2013
# 15  $275,000,000      $73,058,679    $282,778,100    tt0401729  2012
# 15  $275,000,000      $73,058,679    $282,778,100    tt0401729  2012
# 15  $275,000,000      $73,058,679    $282,778,100    tt0401729  2012
# 16  $260,000,000      $200,821,936   $586,477,240    tt0117831  1997
# 17  $260,000,000      $200,821,936   $586,477,240    tt0238137  2001
# 17  $260,000,000      $200,821,936   $586,477,240    tt0238137  2001
# 18  $260,000,000      $200,821,936   $586,477,240    tt0398286  2010
# 18  $260,000,000      $200,821,936   $586,477,240    tt0398286  2010
# 36  $60,000,000       $23,385,416    $48,585,416     tt0167779  1950
# 37  $60,000,000       $23,385,416    $48,585,416     tt0848228  2012
# 37  $60,000,000       $23,385,416    $48,585,416     tt0848228  2012
# 37  $60,000,000       $23,385,416    $48,585,416     tt0848228  2012
# 38  $225,000,000      $291,045,518   $667,999,518    tt0180817  1999
# 38  $225,000,000      $291,045,518   $667,999,518    tt0180817  1999
# 38  $225,000,000      $291,045,518   $667,999,518    tt0180817  1999
# 39  $225,000,000      $291,045,518   $667,999,518    tt0263704  1967
# 40  $225,000,000      $291,045,518   $667,999,518    tt0770828  2013
# 40  $225,000,000      $291,045,518   $667,999,518    tt0770828  2013
# 40  $225,000,000      $291,045,518   $667,999,518    tt0770828  2013
# 41  $225,000,000      $141,621,490   $417,341,288    tt0499448  2008
# 41  $225,000,000      $141,621,490   $417,341,288    tt0499448  2008
# 41  $225,000,000      $141,621,490   $417,341,288    tt0499448  2008
#
#        genres
# 0   Drama
# 1   Drama
# 2   Action
# 2   Adventure
# 2   Fantasy
# 3   Horror
# 4   Action
# 4   Adventure
# 4   Fantasy
# 5   Action
# 5   Adventure
# 5   Sci-Fi
# 6   Action
# 6   Adventure
# 6   Sci-Fi
# 7   Action
# 7   Adventure
# 7   Fantasy
# 8   Horror
# 9   Action
# 9   Adventure
# 9   Thriller
# 10  Action
# 10  Adventure
# 11  Action
# 11  Adventure
# 11  Sci-Fi
# 12  Western
# 13  Action
# 13  Adventure
# 13  Drama
# 14  Action
# 14  Adventure
# 14  Comedy
# 15  Action
# 15  Adventure
# 15  Sci-Fi
# 16  \N
# 17  Drama
# 17  Thriller
# 18  Adventure
# 18  Animation
# 18  Comedy
# 19  Action
# 19  Sci-Fi
# 20  Action
# 20  Adventure
# 20  Sci-Fi
# 21  Action
# 21  Adventure
# 21  Sci-Fi
# 22  Adventure
# 22  Family
# 22  Fantasy
# 23  Action
# 23  Adventure
# 23  Family
# 24  Adventure
# 24  Fantasy
# 25  Adventure
# 25  Fantasy
# 26  Action
# 26  Adventure
# 26  Crime
# 27  Action
# 27  Sci-Fi
# 28  Action
# 28  Adventure
# 28  Fantasy
# 29  Action
# 29  Adventure
# 29  Thriller
# 30  Drama
# 30  War
# 31  Action
# 31  Adventure
# 31  Sci-Fi
# 32  Adventure
# 33  Action
# 33  Adventure
# 33  Sci-Fi
# 34  Drama
# 34  War
# 35  Action
# 35  Adventure
# 35  Sci-Fi
# 36  Adventure
# 37  Action
# 37  Adventure
# 37  Sci-Fi
# 38  Drama
# 38  Family
# 38  Fantasy
# 39  Drama
# 40  Action
# 40  Adventure
# 40  Sci-Fi
# 41  Action
# 41  Adventure
# 41  Family

# %%
##Resetting the index and dropping the previous index column
movie_budgets_df = movie_budgets_df.reset_index()
movie_budgets_df = movie_budgets_df.drop(columns = ['index'])

# %%
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].apply(lambda x: x.replace(',',''))
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].apply(lambda x: x.replace('.',''))
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].apply(lambda x: x.replace('$',''))

# %%
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].astype(int)

# %%
movie_budgets_df = movie_budgets_df.sort_values(by='worldwide_gross', ascending = False)

# %%
movie_budgets_df.head()
# Out:
#    id  release_date   movie production_budget domestic_gross  worldwide_gross  \
# 0  1   Dec 18, 2009  Avatar  $425,000,000      $760,507,625   2776345279
# 2  1   Dec 18, 2009  Avatar  $425,000,000      $760,507,625   2776345279
# 3  1   Dec 18, 2009  Avatar  $425,000,000      $760,507,625   2776345279
# 4  1   Dec 18, 2009  Avatar  $425,000,000      $760,507,625   2776345279
# 5  1   Dec 18, 2009  Avatar  $425,000,000      $760,507,625   2776345279
#
#       tconst startYear     genres
# 0  tt0154182  1941      Drama
# 2  tt0499549  2009      Action
# 3  tt0499549  2009      Adventure
# 4  tt0499549  2009      Fantasy
# 5  tt1775309  2011      Horror

# %% [markdown]
# ## Plot the genres of movies

# %%
sns.set(font_scale=2)
g=sns.barplot(x="genres", y="worldwide_gross", data=movie_budgets_df )
for item in g.get_xticklabels():
    item.set_rotation(45)

# %%
movie_budgets_df.head()
# Out:
#    id  release_date   movie production_budget domestic_gross  worldwide_gross  \
# 0  1   Dec 18, 2009  Avatar  $425,000,000      $760,507,625   2776345279
# 2  1   Dec 18, 2009  Avatar  $425,000,000      $760,507,625   2776345279
# 3  1   Dec 18, 2009  Avatar  $425,000,000      $760,507,625   2776345279
# 4  1   Dec 18, 2009  Avatar  $425,000,000      $760,507,625   2776345279
# 5  1   Dec 18, 2009  Avatar  $425,000,000      $760,507,625   2776345279
#
#       tconst startYear     genres
# 0  tt0154182  1941      Drama
# 2  tt0499549  2009      Action
# 3  tt0499549  2009      Adventure
# 4  tt0499549  2009      Fantasy
# 5  tt1775309  2011      Horror

# %%
sns.set(font_scale=1.2)
sns.catplot(x="genres", y="worldwide_gross", data=movie_budgets_df, kind="bar",height=5,aspect=4 )

# %% [markdown]
# ## Plot the budget and gross

# %%
movie_budgets_df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')

# %%
movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].apply(lambda x: x.strip('$'))
movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].apply(lambda x: x.replace(',',''))
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].apply(lambda x: x.strip('$'))
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].apply(lambda x: x.replace(',',''))

# %%
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].apply(lambda x: x.strip('$'))
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].apply(lambda x: x.replace(',',''))

# %%
movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0  1   Dec 18, 2009  Avatar
# 1  2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2  3   Jun 7, 2019   Dark Phoenix
# 3  4   May 1, 2015   Avengers: Age of Ultron
# 4  5   Dec 15, 2017  Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0  425000000         760507625      2776345279
# 1  410600000         241063875      1045663875
# 2  350000000         42762350       149762350
# 3  330600000         459005868      1403013963
# 4  317000000         620181382      1316721747

# %%
movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].astype(float)
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].astype(float)

# %%
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].astype(float)

# %%
type(movie_budgets_df['production_budget'][0])
# Out:
# numpy.float64

# %%
movie_budgets_df['release_month'] = [a[0:3] for a in movie_budgets_df['release_date']]

# %%
sns.set(font_scale=3)
sns.lmplot(x="production_budget", y="worldwide_gross",hue= 'release_month', data=movie_budgets_df,height=14, aspect=1.1, scatter_kws={'alpha': 0.5})
plt.xlim([-0.5e8, None])
plt.ylim([-0.3e9, None])
# Out:
# (-50000000.0, 884028277.5052383)
# (-300000000.0, 2962684201.576028)

# %%
sns.set(font_scale=3)
sns.lmplot(x="production_budget", y="domestic_gross", hue= 'release_month', data=movie_budgets_df,height=14, aspect=1.1, scatter_kws={'alpha': 0.5})
plt.xlim([-0.5e8, None])
plt.ylim([-0.3e9, None])
# Out:
# (-50000000.0, 884028277.5052383)
# (-300000000.0, 1022566733.3735448)

# %%
money_df.head(100)
# Out:
#       imdb_id                                                           title  \
# 0   tt2488496  Star Wars: Episode VII - The Force Awakens
# 1   tt4154796  Avengers: Endgame
# 2   tt0499549  Avatar
# 3   tt1825683  Black Panther
# 4   tt4154756  Avengers: Infinity War
# 5   tt0120338  Titanic
# 6   tt0369610  Jurassic World
# 7   tt0848228  The Avengers
# 8   tt2527336  Star Wars: Episode VIII - The Last Jedi
# 9   tt3606756  Incredibles 2
# 10  tt6105098  The Lion King
# 11  tt0468569  The Dark Knight
# 12  tt3748528  Rogue One: A Star Wars Story
# 13  tt2527338  Star Wars: Episode IX - The Rise of Skywalker
# 14  tt2771200  Beauty and the Beast
# 15  tt2277860  Finding Dory
# 16  tt4520988  Frozen II
# 17  tt0120915  Star Wars: Episode I - The Phantom Menace
# 18  tt0076759  Star Wars: Episode IV - A New Hope
# 19  tt2395427  Avengers: Age of Ultron
# 20  tt1345836  The Dark Knight Rises
# 21  tt0298148  Shrek 2
# 22  tt0083866  E.T. the Extra-Terrestrial
# 23  tt1979376  Toy Story 4
# 24  tt4154664  Captain Marvel
# 25  tt1951264  The Hunger Games: Catching Fire
# 26  tt0383574  Pirates of the Caribbean: Dead Man's Chest
# 27  tt0110357  The Lion King
# 28  tt4881806  Jurassic World: Fallen Kingdom
# 29  tt0435761  Toy Story 3
# 30  tt0451279  Wonder Woman
# 31  tt1300854  Iron Man 3
# 32  tt3498820  Captain America: Civil War
# 54  2011  Michael Bay         Paramount Pictures             [US]
# 55  2014  Clint Eastwood      Warner Bros.                   [US]
# 56  2002  Peter Jackson       New Line Cinema                [US]
# 57  2016  Byron Howard        Walt Disney Pictures           [US]
# 58  2014  Francis Lawrence    Color Force                    [US]
# 59  2007  Sam Raimi           Columbia Pictures              [US]
# 60  2015  Kyle Balda          Illumination Entertainment     [US]
# 61  2019  Todd Phillips       Warner Bros.                   [US]
# 62  2018  James Wan           DC Comics                      [US]
# 63  2017  Jon Watts           Columbia Pictures              [US]
# 64  2010  Tim Burton          Walt Disney Pictures           [US]
# 65  2014  James Gunn          Marvel Studios                 [US]
# 66  1994  Robert Zemeckis     Paramount Pictures             [US]
# 67  2016  Zack Snyder         Warner Bros.                   [US]
# 68  2017  Andy Muschietti     New Line Cinema                [US]
# 69  2016  David Ayer          Atlas Entertainment            [US]
# 70  2018  David Leitch        Twentieth Century Fox          [US]
# 71  2007  Chris Miller        DreamWorks                     [US]
# 72  2007  Michael Bay         DreamWorks                     [US]
# 73  2008  Jon Favreau         Paramount Pictures             [US]
# 74  2001  Chris Columbus      Warner Bros.                   [US]
# 75  2008  Steven Spielberg    Paramount Pictures             [US]
# 76  2019  Jake Kasdan         Matt Tolmach Productions       [US]
# 77  2001  Peter Jackson       New Line Cinema                [US]
# 78  2017  Taika Waititi       Walt Disney Pictures           [US]
# 79  2010  Jon Favreau         Paramount Pictures             [US]
# 80  2002  George Lucas        Lucasfilm                      [US]
# 81  2007  Gore Verbinski      Walt Disney Pictures           [US]
# 82  1983  Richard Marquand    Lucasfilm                      [US]
# 83  1996  Roland Emmerich     Twentieth Century Fox          [US]
# 84  2003  Gore Verbinski      Walt Disney Pictures           [US]
# 85  2012  Sam Mendes          Metro-Goldwyn-Mayer (MGM)      [US]
# 86  2012  Peter Jackson       Metro-Goldwyn-Mayer (MGM)      [US]
# 87  2009  David Yates         Warner Bros.                   [US]
# 88  2010  David Slade         Summit Entertainment           [US]
# 89  2009  Chris Weitz         Temple Hill Entertainment      [US]
# 90  2010  David Yates         Warner Bros.                   [US]
# 91  1999  M. Night Shyamalan  Hollywood Pictures             [US]
# 92  2009  Pete Docter         Pixar Animation Studios        [US]
# 93  2010  Christopher Nolan   Warner Bros.                   [US]
# 94  2007  David Yates         Warner Bros.                   [US]
# 95  2012  Bill Condon         Summit Entertainment           [US]
# 96  2005  Andrew Adamson      Walt Disney Pictures           [US]
# 97  2013  Zack Snyder         Warner Bros.                   [US]
# 98  2005  Mike Newell         Warner Bros.                   [US]
# 99  1980  Irvin Kershner      Lucasfilm                      [US]
#
#      rank budget_usd us_gross
# 0   519    $245MM     $937MM
# 1   111    $356MM     $858MM
# 2   533    $237MM     $761MM
# 3   269    $200MM     $700MM
# 4   376    $321MM     $679MM
# 5   341    $200MM     $659MM
# 6   1,115  $150MM     $652MM
# 7   781    $220MM     $623MM
# 8   848    $317MM     $620MM
# 9   1,282  $200MM     $609MM
# 10  114    $260MM     $544MM
# 11  211    $185MM     $535MM
# 12  648    $200MM     $532MM
# 13  139    $200MM     $515MM
# 14  738    $160MM     $504MM
# 15  2,562  $200MM     $486MM
# 16  82     $150MM     $477MM
# 17  763    $115MM     $475MM
# 18  690    $11MM      $461MM
# 19  949    $250MM     $459MM
# 20  432    $250MM     $448MM
# 21  2,812  $150MM     $441MM
# 22  1,260  $10MM      $435MM
# 23  207    $200MM     $434MM
# 24  405    $175MM     $427MM
# 25  1,416  $130MM     $425MM
# 26  1,567  $225MM     $423MM
# 27  565    $45MM      $423MM
# 28  756    $170MM     $418MM
# 29  1,588  $200MM     $415MM
# 30  345    $149MM     $413MM
# 31  965    $200MM     $409MM
# 32  1,046  $250MM     $408MM
# 33  523    $78MM      $408MM
# 34  940    $139MM     $407MM
# 35  190    $90MM      $405MM
# 36  352    $63MM      $403MM
# 37  2,323  $200MM     $402MM
# 38  546    $150MM     $401MM
# 39  272    $160MM     $391MM
# 40  836    $200MM     $390MM
# 41  567    $125MM     $381MM
# 42  1,383  $94MM      $381MM
# 43  1,358  $113MM     $380MM
# 44  596    $94MM      $378MM
# 45  1,892  $200MM     $374MM
# 46  1,391  $30MM      $371MM
# 47  2,707  $75MM      $368MM
# 48  5,517  $76MM      $368MM
# 49  1,430  $175MM     $364MM
# 50  451    $58MM      $363MM
# 51  910    $175MM     $356MM
# 52  292    $183MM     $356MM
# 53  1,401  $190MM     $353MM
# 54  2,523  $195MM     $352MM
# 55  1,421  $59MM      $350MM
# 56  956    $94MM      $343MM
# 57  821    $150MM     $341MM
# 58  2,342  $125MM     $337MM
# 59  1,876  $258MM     $337MM
# 60  4,165  $74MM      $336MM
# 61  50     $55MM      $335MM
# 62  516    $160MM     $335MM
# 63  624    $175MM     $334MM
# 64  1,890  $200MM     $334MM
# 65  448    $170MM     $333MM
# 66  222    $55MM      $330MM
# 67  752    $250MM     $330MM
# 68  283    $35MM      $329MM
# 69  267    $175MM     $325MM
# 70  539    $110MM     $325MM
# 71  4,949  $160MM     $323MM
# 72  1,407  $150MM     $319MM
# 73  894    $140MM     $319MM
# 74  280    $125MM     $318MM
# 75  2,134  $185MM     $317MM
# 76  37     $125MM     $317MM
# 77  336    $93MM      $316MM
# 78  303    $180MM     $315MM
# 79  1,559  $200MM     $312MM
# 80  1,490  $115MM     $311MM
# 81  1,863  $300MM     $309MM
# 82  1,570  $32MM      $309MM
# 83  1,882  $75MM      $306MM
# 84  618    $140MM     $305MM
# 85  540    $200MM     $304MM
# 86  695    $180MM     $303MM
# 87  1,252  $250MM     $302MM
# 88  2,928  $68MM      $301MM
# 89  3,084  $50MM      $298MM
# 90  1,158  £150MM     $296MM
# 91  1,301  $40MM      $294MM
# 92  1,126  $175MM     $293MM
# 93  239    $160MM     $293MM
# 94  1,332  $150MM     $292MM
# 95  1,284  $120MM     $292MM
# 96  1,099  $180MM     $292MM
# 97  1,132  $225MM     $291MM
# 98  902    $150MM     $290MM
# 99  1,504  $18MM      $290MM
